# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial.distance import euclidean
from sklearn.cluster import KMeans, DBSCAN
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# Import our dataframe from the previous deliverable

# %%
df = pd.read_csv('data/df5.csv', sep=';', header=0)

# %%
def great_circle_distance(location_a, location_b):
    delta_lat = (location_b[0]-location_a[0]) * np.pi/180
    delta_lon = (location_b[1]-location_a[1]) * np.pi/180
    R = 6371 # mean Earth radius in km
    a = (np.sin(delta_lat/2))**2 + (np.cos(location_a[0]*(np.pi/180)) * np.cos(location_b[0]*(np.pi/180)) * (np.sin(delta_lon/2))**2)
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

# %% [markdown]
# Split the dataframe into US and non-US dataframes.

# %%
df_US = df[(df.countrycode=='US')]
df_US.reset_index(drop=True, inplace=True)
df_US
# Out:
#                                               headline           city  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Dallas man comes down with case of Zika         Dallas
# 4               Zika Concerns are Spreading in Houston        Houston
# ..                                                 ...            ...
# 302                          Dengue Outbreak in Easton         Easton
# 303  Authorities are Worried about the Spread of Va...         Clovis
# 304          More Zika patients reported in Fort Worth     Fort Worth
# 305             Zika symptoms spotted in Boynton Beach  Boynton Beach
# 306                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#      latitude  longitude countrycode  cluster_index
# 0    25.77427  -80.19366          US              0
# 1    40.71427  -74.00597          US              0
# 2    25.79065  -80.13005          US              0
# 3    32.78306  -96.80667          US              0
# 4    29.76328  -95.36327          US              0
# ..        ...        ...         ...            ...
# 302  40.68843  -75.22073          US              0
# 303  36.82523 -119.70292          US              0
# 304  32.72541  -97.32085          US              0
# 305  26.52535  -80.06643          US              0
# 306  33.91371  -98.49339          US              0
#
# [307 rows x 6 columns]

# %%
df_world = df[df['countrycode']!='US']
df_world.reset_index(drop=True, inplace=True)
df_world
# Out:
#                                               headline         city  latitude  \
# 0              Mystery Virus Spreads in Recife, Brazil       Recife  -8.05389
# 1                    Trinidad confirms first Zika case     Trinidad -14.83333
# 2                Geneve Scientists Battle to Find Cure       Geneve  46.20222
# 3                   Zika Infested Monkeys in Sao Paulo    Sao Paulo -23.54750
# 4    San Juan reports 1st U.S. Zika-related death a...     San Juan -31.53750
# ..                                                 ...          ...       ...
# 300                       Influenza Exposure in Muscat       Muscat  23.58413
# 301  Rumors about Rabies spreading in Jerusalem hav...    Jerusalem  31.76904
# 302              More Zika patients reported in Indang       Indang  14.19528
# 303  Suva authorities confirmed the spread of Rotav...         Suva -18.14161
# 304         More Zika patients reported in Bella Vista  Bella Vista  18.45539
#
#      longitude countrycode  cluster_index
# 0    -34.88111          BR              1
# 1    -64.90000          BO             -1
# 2      6.14569          CH              2
# 3    -46.63611          BR              3
# 4    -68.53639          AR             -1
# ..         ...         ...            ...
# 300   58.40778          OM             -1
# 301   35.21633          IL             17
# 302  120.87694          PH              4
# 303  178.44149          FJ             13
# 304  -69.94540          DO              0
#
# [305 rows x 6 columns]

# %% [markdown]
# Plotting the data using latitude and longitude gives us a quick visual of how the data clusters.  Based on the 'visualize_clusters' from the previous section, we see that our parameters specific to the US data may need to be fine tuned

# %%
def visualize_clusters(epsilon, min_points, df):
    locations = np.array(list(zip(df['longitude'], df['latitude'])))
    dbscan_model = DBSCAN(eps=epsilon, min_samples=min_points, metric=great_circle_distance)
    clusters = dbscan_model.fit_predict(locations)
    print(f"Number of Outliers: {(clusters == -1).sum()}")
    print(f"Number of groups: {max(clusters)+1}")
    print(f"Number of headlines: {len(clusters)}")
    c = np.array(clusters)
    plt.scatter(df['longitude'],df['latitude'], c=c, cmap='nipy_spectral')
    plt.show()
    #df.drop(['cluster_index'], axis=1)
    df.loc[:, 'cluster_index'] = clusters
    return df

# %%
visualize_clusters(100, 3, df_US)
# Out:
# Number of Outliers: 22
# Number of groups: 10
# Number of headlines: 307
# /home/chris/.local/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                               headline           city  \
# 0                             Zika Outbreak Hits Miami          Miami
# 1                      Could Zika Reach New York City?  New York City
# 2                    First Case of Zika in Miami Beach    Miami Beach
# 3              Dallas man comes down with case of Zika         Dallas
# 4               Zika Concerns are Spreading in Houston        Houston
# ..                                                 ...            ...
# 302                          Dengue Outbreak in Easton         Easton
# 303  Authorities are Worried about the Spread of Va...         Clovis
# 304          More Zika patients reported in Fort Worth     Fort Worth
# 305             Zika symptoms spotted in Boynton Beach  Boynton Beach
# 306                     Zika Outbreak in Wichita Falls  Wichita Falls
#
#      latitude  longitude countrycode  cluster_index
# 0    25.77427  -80.19366          US              0
# 1    40.71427  -74.00597          US              1
# 2    25.79065  -80.13005          US              0
# 3    32.78306  -96.80667          US              2
# 4    29.76328  -95.36327          US              2
# ..        ...        ...         ...            ...
# 302  40.68843  -75.22073          US              1
# 303  36.82523 -119.70292          US              3
# 304  32.72541  -97.32085          US              2
# 305  26.52535  -80.06643          US              0
# 306  33.91371  -98.49339          US              2
#
# [307 rows x 6 columns]

# %% [markdown]
# Now that we have clustered the US data individually, we can perform some summary statistics about the sample.
# We can count how many headlines belong to each cluster using the 'groupby' method of pandas.
# We can also take a mean average of the [lat|long]itude of each cluster.
# *For a more accurate geographic center, the great circle formula could be added to the aggregate list with a custom formula. See addition below

# %%
#US_group order by cluster size and add aggregate info
def order_clusters(df):
    df_cluster_order = df.groupby('cluster_index').agg(
        #cluster_index=('cluster_index', max),
        cluster_count=('cluster_index', 'count'),
        mean_lon=('longitude', 'mean'),
        mean_lat=('latitude', 'mean')
    ).sort_values('cluster_count', ascending=False).reset_index()
    
    
    return df_cluster_order

# %%
aggregate = order_clusters(df_US)
aggregate
# Out:
#     cluster_index  cluster_count    mean_lon   mean_lat
# 0               2             81  -92.409498  35.741936
# 1               1             69  -74.909526  40.323022
# 2               0             66  -81.755993  31.991700
# 3               3             34 -117.944434  34.123855
# 4              -1             22 -115.246236  38.462043
# 5               4             15 -122.072558  37.780540
# 6               6              7 -105.080220  39.904549
# 7               5              4 -122.283178  47.478502
# 8               7              3 -111.825210  40.716337
# 9               8              3  -78.805197  35.606263
# 10              9              3 -114.895820  35.787483

# %%
for col in aggregate.columns:
    print(col)
# Out:
# cluster_index
# cluster_count
# mean_lon
# mean_lat

# %% [markdown]
# We now have a list with the biggest clusters first.  We can use padas 'Catagoricals' to use the cluster_index order as our headlines sort_values order.

# %%
sorter=aggregate['cluster_index'].to_list()
print(sorter)
# Out:
# [2, 1, 0, 3, -1, 4, 6, 5, 7, 8, 9]

# %% [markdown]
# To catagorize the df_US['cluster_index'], we use...

# %%
df_US.cluster_index = df_US.cluster_index.astype("category")
df_US.cluster_index.cat.set_categories(sorter, inplace=True)
# Out:
# /home/chris/.local/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ...and now if we use sort values by cluster_index, we should see the headlines in our specified order...

# %%
df_US = df_US[df_US['cluster_index']!= -1 ].sort_values(['cluster_index'])

# %% [markdown]
# Add an extra column with the distance from the center point by using 'Merge'.

# %%
df_merge = pd.merge(df_US, aggregate, on='cluster_index', how='left')

# %%
df_US['center_distance'] = great_circle_distance([df_merge['mean_lat'],df_merge['mean_lon']], [df_merge['latitude'],df_merge['longitude']])
df_US
# Out:
#                                               headline           city  \
# 306                     Zika Outbreak in Wichita Falls  Wichita Falls
# 215               Deerfield tests new cure for Measles      Deerfield
# 111         Benton Residents Recieve Pneumonia vaccine         Benton
# 110         Frisco Woman Tests Positive For Zika Virus         Frisco
# 109     Zika-carrying mosquitoes discovered in Ardmore        Ardmore
# ..                                                 ...            ...
# 267  Fayetteville authorities confirmed the spread ...   Fayetteville
# 117  More people in Durham are infected with Chlamy...         Durham
# 94                    Will HIV vaccine help Las Vegas?      Las Vegas
# 254         Respiratory Syncytial Virus Hits Henderson      Henderson
# 133            How to Avoid Pneumonia in Bullhead City  Bullhead City
#
#      latitude  longitude countrycode cluster_index  center_distance
# 306  33.91371  -98.49339          US             2              NaN
# 215  42.17114  -87.84451          US             2       707.299321
# 111  34.56454  -92.58683          US             2       363.917142
# 110  33.15067  -96.82361          US             2       173.366660
# 109  34.17426  -97.14363          US             2       566.251021
# ..        ...        ...         ...           ...              ...
# 267  35.05266  -78.87836          US             8        11.335327
# 117  35.99403  -78.89862          US             8        18.401372
# 94   36.17497 -115.13722          US             9       566.251021
# 254  36.03970 -114.98194          US             9        26.864477
# 133  35.14778 -114.56830          US             9       253.769500
#
# [285 rows x 7 columns]

# %% [markdown]
# Once the distance from centre data is calculated, we can sort by both cluster index and then by distance from centre.

# %%
df_US = df_US.sort_values(['cluster_index', 'center_distance'], ascending=[True,True])

# %% [markdown]
# After a common word search in linux terminal we see that the most common disease words used in headlines.txt are as follows
#
# zika
# Hepatitis
# West Nile
# Mad Cow
# Malaria
# Tugerculosis
# Measles
# Dengue
# Rabies
# Norovirus
# Rotavirus
# Pneumonia
# Rhinovirus
# HIV
# Varicella
# Mumps
# Meningitis
# Chickungunya
# Herpes
# Chlamydia
# Gonorrhea
# Chickenpox
# Bronchitis
# Syphilis
# Flu

# %% [raw]
# awk ' { for (i=1; i<=NF; i++) print $i } ' headlines.txt | sort | uniq -c | sort -n

# %% [markdown]
# We can compile a regex search parameter with all the above diseases and match against the headlines.  Any headlines not matching can be removed entirely from our analysis.

# %%
import re

regex = r"(?P<disease>(\b(zika|Hepatitis|West Nile|Mad Cow|Malaria|Tuberculosis|Measles|Dengue|Rabies|Norovirus|Rotavirus|Pneumonia|Rhinovirus|HIV|Varicella|Mumps|Meningitis|Chickungunya|Herpes|Chlamydia|Gonorrhea|Chickenpox|Bronchitis|Syphilis|Flu)\b))"
disease_regex= re.compile(regex, flags=re.IGNORECASE)

# %%
matchList = []
for hdl in df_US['headline']:
    try:
        m = re.search(disease_regex, hdl)
        matchList.append(m.group('disease'))
    except:
        matchList.append("NaN")
#print(matchList)
df_US['disease'] = matchList
df_US
# Out:
#                                               headline           city  \
# 276           Marquette tests new cure for Hepatitis A      Marquette
# 273                           Mumps Outbreak in Joplin         Joplin
# 251  Rumors about Rotavirus Spreading in Joliet hav...         Joliet
# 261    Hepatitis D Symptoms Spread all over Evansville     Evansville
# 224          Tupelo Residents Recieve Syphilis vaccine         Tupelo
# ..                                                 ...            ...
# 117  More people in Durham are infected with Chlamy...         Durham
# 69                Will Norovirus vaccine help Raleigh?        Raleigh
# 254         Respiratory Syncytial Virus Hits Henderson      Henderson
# 133            How to Avoid Pneumonia in Bullhead City  Bullhead City
# 94                    Will HIV vaccine help Las Vegas?      Las Vegas
#
#      latitude  longitude countrycode cluster_index  center_distance    disease
# 276  46.54354  -87.39542          US             2         7.429193  Hepatitis
# 273  37.08423  -94.51328          US             2        14.666990      Mumps
# 251  41.52519  -88.08340          US             2        30.242644  Rotavirus
# 261  37.97476  -87.55585          US             2        34.031097  Hepatitis
# 224  34.25807  -88.70464          US             2        35.310793   Syphilis
# ..        ...        ...         ...           ...              ...        ...
# 117  35.99403  -78.89862          US             8        18.401372  Chlamydia
# 69   35.77210  -78.63861          US             8       971.311517  Norovirus
# 254  36.03970 -114.98194          US             9        26.864477        NaN
# 133  35.14778 -114.56830          US             9       253.769500  Pneumonia
# 94   36.17497 -115.13722          US             9       566.251021        HIV
#
# [285 rows x 8 columns]

# %% [markdown]
# We could now do a 'double' group by 'cluster' and 'disease' and get an aggregate of the new data.

# %%
def order_diseaseByCluster(df):
    df_clusDisease = df.groupby(['cluster_index', 'disease']).agg(
        #cluster_index=('cluster_index', max),
        #cluster_count=('cluster_index', 'count'),
        disease_count=('disease', 'count'),
        mean_lon=('longitude', 'mean'),
        mean_lat=('latitude', 'mean'),
    ).sort_values(['disease_count'], ascending=[False]).reset_index()
    return df_clusDisease

# %% [markdown]
# ### Top 10 Clusters

# %%
df_outbreaks = order_diseaseByCluster(df_US)
df_outbreaks = df_outbreaks[df_outbreaks['disease']!="NaN"]
df_outbreaks = df_outbreaks.head(10).reset_index()
df_outbreaks
# Out:
#    index cluster_index    disease  disease_count    mean_lon   mean_lat
# 0      0             0       Zika             42  -81.303284  28.986624
# 1      1             2       Zika             32  -94.826502  32.091484
# 2      2             1  Hepatitis             11  -74.860295  40.120890
# 3      3             2  Hepatitis              8  -89.697745  39.689865
# 4      6             3       Zika              6 -117.437862  33.602448
# 5      7             1     Dengue              6  -75.258700  41.917445
# 6      9             1      Mumps              5  -74.929072  39.627760
# 7     10             2  Rotavirus              5  -90.307192  39.549122
# 8     11             1    Measles              4  -73.974380  40.725658
# 9     12             1       Zika              4  -74.774480  40.312742

# %% [markdown]
# From this summary of disease count, we can see the biggest outbreaks are Zika (clusters 0 and 2).

# %%
disease_set = (set(df_outbreaks['disease']))

# %%
fig, ax = plt.subplots(figsize=(12, 8))

usa = Basemap(projection='merc',llcrnrlat=20,urcrnrlat=50,\
            llcrnrlon=-130,urcrnrlon=-60,lat_ts=20,resolution='c', lat_0=30.0, lon_0=-100)
#usa = Basemap()
usa.drawcoastlines()
#usa.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
usa.drawmapboundary()
#usa.shadedrelief()
for disease in disease_set:
    df_group = df_outbreaks[df_outbreaks['disease']==disease]
    usa.scatter(df_group['mean_lon'].to_list(), df_group['mean_lat'].to_list(),latlon=True, label=disease, s=df_group['disease_count']*40)
    #ax.annotate(df_group['disease_count'],df_group['mean_lon'].to_list(), df_group['mean_lat'].to_list())
plt.legend(loc='lower right', labelspacing=2)   
plt.show()

# %% [markdown]
# ### Doing the same for the world data gives...

# %%
visualize_clusters(875, 4, df_world)
# Out:
# Number of Outliers: 20
# Number of groups: 11
# Number of headlines: 305
# /home/chris/.local/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                               headline         city  latitude  \
# 0              Mystery Virus Spreads in Recife, Brazil       Recife  -8.05389
# 1                    Trinidad confirms first Zika case     Trinidad -14.83333
# 2                Geneve Scientists Battle to Find Cure       Geneve  46.20222
# 3                   Zika Infested Monkeys in Sao Paulo    Sao Paulo -23.54750
# 4    San Juan reports 1st U.S. Zika-related death a...     San Juan -31.53750
# ..                                                 ...          ...       ...
# 300                       Influenza Exposure in Muscat       Muscat  23.58413
# 301  Rumors about Rabies spreading in Jerusalem hav...    Jerusalem  31.76904
# 302              More Zika patients reported in Indang       Indang  14.19528
# 303  Suva authorities confirmed the spread of Rotav...         Suva -18.14161
# 304         More Zika patients reported in Bella Vista  Bella Vista  18.45539
#
#      longitude countrycode  cluster_index
# 0    -34.88111          BR              0
# 1    -64.90000          BO              0
# 2      6.14569          CH              1
# 3    -46.63611          BR              0
# 4    -68.53639          AR              0
# ..         ...         ...            ...
# 300   58.40778          OM             -1
# 301   35.21633          IL              9
# 302  120.87694          PH              2
# 303  178.44149          FJ             -1
# 304  -69.94540          DO              0
#
# [305 rows x 6 columns]

# %%
aggregate = order_clusters(df_world)

# %%
sorter = aggregate['cluster_index'].to_list()

# %%
print(sorter)
# Out:
# [0, 2, 1, 3, 5, 9, 4, 7, 6, 8, -1]

# %%
df_world.cluster_index = df_world.cluster_index.astype("category")
df_world.cluster_index.cat.set_categories(sorter, inplace=True)
df_world = df_world[df_world['cluster_index']!= -1 ].sort_values(['cluster_index'])
df_world
# Out:
#                                               headline          city  \
# 1                    Trinidad confirms first Zika case      Trinidad
# 137             Tocumen tests new cure for Hepatitis A       Tocumen
# 19                 Zika outbreak in Piracicaba, Brazil    Piracicaba
# 20                 Lima tries to address Zika Concerns          Lima
# 62   Authorities are Worried about the Spread of No...  Buenos Aires
# ..                                                 ...           ...
# 64      Tokyo Encounters Severe Symptoms of Meningitis         Tokyo
# 240                           Tuberculosis Hits Luanda        Luanda
# 199  The Spread of Malaria in Brazzaville has been ...   Brazzaville
# 270                    Pneumonia has not Left Kinshasa      Kinshasa
# 101                Hepatitis E has not Left Libreville    Libreville
#
#      latitude  longitude countrycode cluster_index
# 1   -14.83333  -64.90000          BO             0
# 137   9.08939  -79.38310          PA             0
# 19  -22.72528  -47.64917          BR             0
# 20  -12.04318  -77.02824          PE             0
# 62  -34.61315  -58.37723          AR             0
# ..        ...        ...         ...           ...
# 64   35.68950  139.69171          JP             6
# 240  -8.83682   13.23432          AO             8
# 199  -4.26613   15.28318          CG             8
# 270  -4.32758   15.31357          CD             8
# 101   0.39241    9.45356          GA             8
#
# [278 rows x 6 columns]

# %%
df_merge = pd.merge(df_world, aggregate, on='cluster_index', how='left')

# %%
df_world['center_distance'] = great_circle_distance([df_merge['mean_lat'],df_merge['mean_lon']], [df_merge['latitude'],df_merge['longitude']])

# %%
df_world = df_world.sort_values(['cluster_index', 'center_distance'], ascending=[True,True])

# %%
matchList = []
for hdl in df_world['headline']:
    try:
        m = re.search(disease_regex, hdl)
        matchList.append(m.group('disease'))
    except:
        matchList.append("NaN")
#print(matchList)
df_world['disease'] = matchList
df_world
# Out:
#                                               headline         city  latitude  \
# 185                 Zika symptoms spotted in Quisqueya    Quisqueya  18.55542
# 192              Will Hepatitis B vaccine help La Paz?       La Paz -16.50000
# 273            More Zika patients reported in Botucatu     Botucatu -22.88583
# 261                      Zika case reported in Reynosa      Reynosa  26.08061
# 268                     Zika case reported in Limoeiro     Limoeiro  -7.87472
# ..                                                 ...          ...       ...
# 64      Tokyo Encounters Severe Symptoms of Meningitis        Tokyo  35.68950
# 270                    Pneumonia has not Left Kinshasa     Kinshasa  -4.32758
# 199  The Spread of Malaria in Brazzaville has been ...  Brazzaville  -4.26613
# 240                           Tuberculosis Hits Luanda       Luanda  -8.83682
# 101                Hepatitis E has not Left Libreville   Libreville   0.39241
#
#      longitude countrycode cluster_index  center_distance       disease
# 185  -69.40814          DO             0        20.908559          Zika
# 192  -68.15000          BO             0        75.398904     Hepatitis
# 273  -48.44500          BR             0        88.033546          Zika
# 261  -98.28835          MX             0       116.109199          Zika
# 268  -35.45028          BR             0       173.661396          Zika
# ..         ...         ...           ...              ...           ...
# 64   139.69171          JP             6      1531.168805    Meningitis
# 270   15.31357          CD             8       257.158495     Pneumonia
# 199   15.28318          CG             8       373.107187       Malaria
# 240   13.23432          AO             8       633.871771  Tuberculosis
# 101    9.45356          GA             8      3281.201753     Hepatitis
#
# [278 rows x 8 columns]

# %%
df_outbreaks = order_diseaseByCluster(df_world)
df_outbreaks = df_outbreaks[df_outbreaks['disease']!="NaN"]
df_outbreaks = df_outbreaks.head(10).reset_index()
df_outbreaks
# Out:
#    index cluster_index    disease  disease_count    mean_lon   mean_lat
# 0      0             0       Zika             62  -68.914862   1.998182
# 1      1             2       Zika             52  104.381148  12.849078
# 2      2             1    Mad Cow             19    3.072171  49.340101
# 3      4             1        Flu              8   -0.586210  41.060474
# 4      5             0  Hepatitis              6  -75.203013  29.154570
# 5      7             1  Hepatitis              5    1.374628  48.789278
# 6      8             1     Rabies              4   -0.556280  44.361877
# 7      9             2  West Nile              4  100.927980   7.134362
# 8     10             3       Zika              3  147.424987 -26.820237
# 9     11             2  Hepatitis              3  120.427150  24.832527

# %%
disease_set = (set(df_outbreaks['disease']))

# %%
print(disease_set)
# Out:
# {'Hepatitis', 'Flu', 'Rabies', 'Zika', 'West Nile', 'Mad Cow'}

# %%
fig, ax = plt.subplots(figsize=(12, 8))

world = Basemap()
#usa = Basemap()
world.drawcoastlines()
#usa.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
world.drawmapboundary()
#usa.shadedrelief()
for disease in disease_set:
    df_group = df_outbreaks[df_outbreaks['disease']==disease]
    world.scatter(df_group['mean_lon'].to_list(), df_group['mean_lat'].to_list(),latlon=True, label=disease, s=df_group['disease_count']*40)
    #ax.annotate(df_group['disease_count'],df_group['mean_lon'].to_list(), df_group['mean_lat'].to_list())
plt.legend(loc='lower left', labelspacing=2)   
plt.show()
